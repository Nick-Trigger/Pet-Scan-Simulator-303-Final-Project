# %% [markdown]
# **A PET Scan Simulator**
#
# By: Nicholas Trigger and James Bradley

# %%
from ipywidgets import interact
import ipywidgets as widgets
import matplotlib.pyplot as plt
import numpy as np
import plotly.graph_objects as go

# %% [markdown]
# ex:

# %%
def plot_func(freq):
    x = np.linspace(0, 2 * np.pi, 100)
    y = np.sin(freq * x)
    plt.clf()  # Clear previous plot
    plt.plot(x, y)
    plt.show()

interact(plot_func, freq=widgets.FloatSlider(min=1.0, max=10.0, step=0.5, value=5.0))
# Out:
# interactive(children=(FloatSlider(value=5.0, description='freq', max=10.0, min=1.0, step=0.5), Output()), _dom…
# <function __main__.plot_func(freq)>

# %%
x = np.linspace(0, 10, 100)

# Create figure with multiple traces for slider steps
fig = go.Figure()
for step in range(5):
    fig.add_trace(
        go.Scatter(
            x=x,
            y=np.sin(step * x),
            visible=(step == 0),  # Make only the first trace visible initially
            name=f"Step {step}"
        )
    )

# Create slider steps
steps = []
for i in range(len(fig.data)):
    step = dict(
        method="update",
        args=[{"visible": [False] * len(fig.data)}, {"title": f"Step {i}"}],
    )
    step["args"][0]["visible"][i] = True
    steps.append(step)

# Add slider to layout
sliders = [
    dict(
        active=0,
        currentvalue={"prefix": "Frequency: "},
        pad={"t": 50},
        steps=steps
    )
]

fig.update_layout(sliders=sliders)
fig.show()

# %%
import plotly.graph_objects as go
import numpy as np

# Create a random image
img = np.random.randint(0, 255, (100, 100), dtype=np.uint8)

# Display the image
fig = go.Figure(go.Image(z=img))
fig.show()
